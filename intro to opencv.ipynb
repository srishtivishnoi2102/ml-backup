# %%
import matplotlib.pyplot as plt

# %%
import cv2
import time

# %%
video=cv2.VideoCapture(0)
check,frame=video.read()
# print(frame)
print(check)
plt.imshow(frame)
time.sleep(4)

video.release()
# Out:
# True

# %%
frame.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(frame)

# %%
img = cv2.imread("datasets/srishti.jpg",0)

# %%
plt.imshow(img)

# %%
img2=cv2.resize(img,(img.shape[1]//4,img.shape[0]//4))

# %%
plt.imshow(img2)
