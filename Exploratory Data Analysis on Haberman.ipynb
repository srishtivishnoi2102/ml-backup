# %% [markdown]
# # (3.1) Basic Terminology

# %% [markdown]
# * What is EDA?
# * Data-point/vector/Observation
# * Data-set.
# * Feature/Variable/Input-variable/Dependent-varibale
# * Label/Indepdendent-variable/Output-varible/Class/Class-label/Response label
# * Vector: 2-D, 3-D, 4-D,.... n-D

# %% [markdown]
# ## Haberman Cancer dataset

# %% [markdown]
# *  Objective: Classify a new sample as belonging to one of the 2 classes given the 3 features.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


'''downlaod iris.csv from https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'''
#Load Iris.csv into a pandas dataFrame.
data = pd.read_csv("datasets/haberman.csv")

# %%
# Out:
# array([1, 2], dtype=int64)

# %%
data.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
# (Q) how many data-points and features?
data.shape
# Out:
# (306, 4)

# %%
#(Q) What are the column names in our dataset?
data.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
# how many classes are present?
data['status'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
#(Q) How many data points for each class are present? 
#(or) How many flowers for each species are present?

data["status"].value_counts()
# balanced-dataset vs imbalanced datasets
#Iris is a balanced dataset as the number of data points for every class is 50.
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
# (3.2) 2-D Scatter Plot

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

iris.plot(kind='scatter', x='year', y='nodes') ;
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/status.

# %%
# 2-D Scatter plot with color-coding for each status/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="status", size=4) \
   .map(plt.scatter, "year", "nodes") \
   .add_legend();
plt.show();

# Notice that orange and blue data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 3C2 = 3.

# %% [markdown]
# Observation(s):
#
# Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.
# Seperating Versicolor from Viginica is much harder as they have considerable overlap.
#
#
# ## 3D Scatter plot
# https://plot.ly/pandas/3d-scatter-plots/
#
# Needs a lot to mouse interaction to interpret data.
#
# What about 4-D, 5-D or n-D scatter plot?

# %% [markdown]
# #  (3.3) Pair-plot

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.
plt.close();
sns.set_style("whitegrid");
sns.pairplot(data, hue="status", size=3);
plt.show()
# NOTE: the diagnol elements are PDFs for each feature. PDFs are expalined below.

# %% [markdown]
# # (3.4) Histogram, PDF, CDF

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
import numpy as np
data_1 = data.loc[iris["status"] == 1]
data_2 = data.loc[iris["status"] == 2]
plt.plot(data_1["age"], np.zeros_like(data_1['age']), 'o')
plt.plot(data_2["age"], np.zeros_like(data_2['age']), 'o')

plt.show()
#Disadvantages of 1-D scatter plot: Very hard to make sense as points 
#are overlapping a lot.
#Are there better ways of visualizing 1-D scatter plots?

# %%
sns.FacetGrid(data, hue="status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Srishti Vishnoi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Srishti Vishnoi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
