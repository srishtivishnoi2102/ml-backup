# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# import random as r
# import scipy.stats as S
rawdata = pd.read_csv("datasets/data.csv")

# %%
rawdata.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
y=rawdata['diagnosis'].values
x=rawdata[['radius_mean','texture_mean']].values
y=y.reshape(len(y),1)

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder=LabelEncoder()
y=labelEncoder.fit_transform(y)
# Out:
# C:\Users\Srishti Vishnoi\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2)

ytrain=ytrain.reshape(len(ytrain),1)
ytest=ytest.reshape(len(ytest),1)

# %%
def sigmoid(z):
    return 1/(1+ np.exp(-z))

# %%
# def logistic_loss(y_class,y_h_function_value):
#     return -np.mean( y_class*np.log(y_h_function_value) + (1-y_class)*np.log(1- y_h_function_value) )


def logistic_loss(y,h):    
    return -np.mean( y*np.log(h) + (1-y)*np.log(1-h) )

# %%
weights_old=np.random.randn(2,1)
weights_new=weights_old
bias_old= np.random.randn(1,1)
bias_new=bias_old
learning_rate=0.01

# %%
# training procedure
m=len(ytrain)
for each in range(5000):
    Z_old=np.matmul(xtrain,weights_old)+bias_old
    h_value_old=sigmoid(Z_old)
#     print(h_value_old)
    loss=logistic_loss(ytrain,h_value_old)
    print("loss in {}th iteration is: {}".format(each,loss))
    dZ=h_value_old-ytrain

#     bias_new = bias_old - learning_rate *   
    
    dWeights= np.matmul(xtrain.T,dZ) 
    dBias=np.sum(dZ)
    
    weights_new=weights_old - learning_rate*dWeights
    bias_new= bias_old - learning_rate*dBias

    Z_new=np.matmul(xtrain,weights_new)+bias_new
    h_value_new=sigmoid(Z_new)
    
    if abs(logistic_loss(ytrain,h_value_old)-logistic_loss(ytrain,h_value_new))<0.01:
        break
    bias_old=bias_new
    weights_old=weights_new
# Out:
# C:\Users\Srishti Vishnoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\Srishti Vishnoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in multiply
# loss in 0th iteration is: nan
# loss in 1th iteration is: nan
# loss in 2th iteration is: 102.22859858095825
# loss in 3th iteration is: nan
# loss in 4th iteration is: nan
# loss in 5th iteration is: nan
# loss in 6th iteration is: nan
# loss in 7th iteration is: nan
# loss in 8th iteration is: nan
# loss in 9th iteration is: nan
# loss in 10th iteration is: inf
# loss in 11th iteration is: nan
# loss in 12th iteration is: nan
# loss in 13th iteration is: nan
# loss in 14th iteration is: nan
# loss in 15th iteration is: nan
# loss in 16th iteration is: nan
# loss in 17th iteration is: nan
# loss in 18th iteration is: nan
# loss in 19th iteration is: nan
# loss in 20th iteration is: nan
# loss in 21th iteration is: nan
# ...

# %%
weights_new
# Out:
# array([[110.15872452],
#        [-49.02038924]])

# %%
weights_old
# Out:
# array([[110.15872452],
#        [-49.02038924]])
