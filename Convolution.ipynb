# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=plt.imread("cat.4001.jpg")

# %%
plt.imshow(img)

# %%
a=np.random.randn(3,3)
x=cv2.filter2D(img,-2,a)
plt.imshow(x)

# %%
x.shape
# Out:
# (415, 498, 3)

# %%
b=np.random.randn(200,200)

# %%
plt.imshow(b)

# %%
b=cv2.filter2D(b,-2,a)
plt.imshow(b)
